# %%
using CRCBS
using Distributions
using HCubature
using CSV
# Out:
# ┌ Info: Recompiling stale cache file /home/peltzer/.julia/compiled/v1.0/CRCBS/26Ksw.ji for CRCBS [edef75b8-3ac4-11e9-0392-bf149c536ee3]
# └ @ Base loading.jl:1190
# ┌ Warning: Package CRCBS does not have JLD in its dependencies:
# │ - If you have CRCBS checked out for development and have
# │   added JLD as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with CRCBS
# └ Loading JLD into CRCBS from project dependency, future warnings for CRCBS are suppressed.
# WARNING: Method definition get_dist_matrix(LightGraphs.AbstractGraph{T} where T) in module CRCBS at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:11 overwritten at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:11.
# ┌ Warning: Replacing docs for `CRCBS.get_dist_matrix :: Tuple{LightGraphs.AbstractGraph}` in module `CRCBS`
# └ @ Base.Docs docs/Docs.jl:223
# WARNING: Method definition pad_matrix(Array{T, 2}, Tuple{Int64, Int64}, T) where {T} in module CRCBS at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:22 overwritten at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:22.
# ┌ Warning: Replacing docs for `CRCBS.pad_matrix :: Union{Tuple{T}, Tuple{Array{T,2},Tuple{Int64,Int64},T}} where T` in module `CRCBS`
# └ @ Base.Docs docs/Docs.jl:223
# WARNING: Method definition compute_distance_matrix(Any, Any) in module CRCBS at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:32 overwritten at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:32.
# WARNING: Method definition sample_wo_repl(Any, Any) in module CRCBS at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:135 overwritten at /home/peltzer/.julia/dev/CRCBS/src/utils.jl:135.

# %%
name = "Timing_test_13"
num_agents = tuple(50)
grid_x = tuple(40)
grid_y = tuple(40)
filling_density = tuple(1.0)
lambda = 0.2
epsilon = 0.2
t_delay = 0.2
max_num_experiments = 5
num_trials = 2000

data = run_experiment_set_CRCBS(name,num_agents,grid_x,grid_y,filling_density,lambda,epsilon,t_delay,max_num_experiments,num_trials)
# Out:
# Started
# Check1
# Check2
# ASTAR: 50
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 12 and 46 conflict at node 741
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 12 and 46 conflict at node 741
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 12 and 46 conflict at node 742
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 12 and 46 conflict at node 742
# ASTAR: 1
# ASTAR: 1
#
#
# Optimal Solution Found! Cost = 1298
# Time spent on probability count: 51.98074882000001
# Time spent on path finding: 4.153113488
# Time spent performing optimization: 66.390531578
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found52 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012680421000170262
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found401 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.19635069882303346
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found48 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.022642328122897164
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0016506019613564751
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found60 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.029576806918987397
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found23 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01118824128296202
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found33 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01732238657581637
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found22 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009608581077576495
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00654907689457985
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found5 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0021505828495221803
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0018041651470901655
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found149 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07973650936955085
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found80 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0340453042261754
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0017787746667668536
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found130 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07518046284293578
# Possible interactions
#
#  I found149 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07980952160538855
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found148 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0767305021582669
#
#  I found17 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.008052672228993168
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found136 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07787456401781125
# Possible interactions
#
#  I found150 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07957335371681641
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found35 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.020106413536260713
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found34 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.014324199782984215
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.001487294742323384
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found33 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.011184732149916218
# Possible interactions
# Possible interactions
#
#  I found131 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07311839793039865
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found60 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0306190341393485
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found18 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.008052672228993168
# Possible interactions
# Possible interactions
#
#  I found137 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07869766151862828
# Possible interactions
# Possible interactions
#
#  I found54 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.021406320227963942
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.006109265811937821
# Possible interactions
#
#  I found49 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.028756916957799507
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found372 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.16818765089691887
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found137 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.06696128246939478
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found5 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0018041651470901655
#
#  I found134 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07924963706624046
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005132146319483199
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found68 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0011105413983559234
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01852327903878487
# Possible interactions
#
#  I found26 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009263718008829159
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found28 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.017322316247275697
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found152 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07977128641590721
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0018047469538795757
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0029176906388166226
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found10 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005132140343063994
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0018041651470901655
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found116 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.06252026613736757
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found10 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004211143359113715
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found118 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0569102649225131
# Possible interactions
#
#  I found156 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07409863352389302
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.001049171903891676
# Possible interactions
#
#  I found10 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005147214324220935
#
#  I found161 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07869766151862828
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found171 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07261197686376501
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found57 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0306190341393485
# Possible interactions
# Possible interactions
#
#  I found30 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.014324199782984215
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.000726065999602679
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0029170039146603397
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found22 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.001681290111466449
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found8 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0016506019613564751
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found16 conflicts!
# This is out of 2000 trials, and the collision probability is 0.08671972439781628
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found39 conflicts!
# This is out of 2000 trials, and the collision probability is 0.11337653376025379
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found10 conflicts!
# This is out of 2000 trials, and the collision probability is 0.07922876292652024
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found124 conflicts!
# This is out of 2000 trials, and the collision probability is 0.17855497219543826
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found29 conflicts!
# This is out of 2000 trials, and the collision probability is 0.12469172718925521
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found26 conflicts!
# This is out of 2000 trials, and the collision probability is 0.10072652249104473
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found4 conflicts!
# This is out of 2000 trials, and the collision probability is 0.07144544858203634
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found211 conflicts!
# This is out of 2000 trials, and the collision probability is 0.28080643924137094
# Interaction at edge!
#
#  I found26 conflicts!
# This is out of 2000 trials, and the collision probability is 0.11337653376025379
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found5 conflicts!
# This is out of 2000 trials, and the collision probability is 0.05520408278949299
# Interaction at edge!
#
#  I found256 conflicts!
# This is out of 2000 trials, and the collision probability is 0.2878595233491397
# Interaction at edge!
#
#  I found2 conflicts!
# This is out of 2000 trials, and the collision probability is 0.034264199501967754
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found7 conflicts!
# This is out of 2000 trials, and the collision probability is 0.05473809032431029
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found256 conflicts!
# This is out of 2000 trials, and the collision probability is 0.29857690435237894
# Interaction at edge!
# Interaction at edge!
#
#  I found3 conflicts!
# This is out of 2000 trials, and the collision probability is 0.02732275551281952
# Interaction at edge!
# Interaction at edge!
#
#  I found15 conflicts!
# This is out of 2000 trials, and the collision probability is 0.06123980083822597
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found10 conflicts!
# This is out of 2000 trials, and the collision probability is 0.10072652249104473
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# ASTAR: 50
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 25 and 29 conflict at node 341
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 25 and 29 conflict at node 341
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 25 and 29 conflict at node 382
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 25 and 29 conflict at node 382
# ASTAR: 1
# ASTAR: 1
#
#
# Optimal Solution Found! Cost = 1436
# Time spent on probability count: 83.203050797
# Time spent on path finding: 4.624899825000003
# Time spent performing optimization: 98.347413956
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found51 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02140631744750304
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found182 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.09934675370924476
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found133 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07558370371619998
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0008091024138528613
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found19 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009263718008829159
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found23 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.012766440451814975
# Possible interactions
#
#  I found9 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004211143359113715
#
#  I found143 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07790782521909194
# Possible interactions
#
#  I found14 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004674689270997448
#
#  I found133 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07747260621629039
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found15 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.006109281811672591
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0038388273860070032
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0005114985667532502
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found167 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07790782526378506
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005132140343063994
# Possible interactions
# Possible interactions
#
#  I found52 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.026953065946356863
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found144 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07957306821525333
# Possible interactions
#
#  I found33 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.020106390906710226
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found26 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.015846501759129057
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005147230838563536
#
#  I found9 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00654907689457985
# Possible interactions
#
#  I found158 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07518046284293578
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found32 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.014324199782984215
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012008589155807529
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0021486892045596336
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found166 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0767305021582669
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found265 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.13583304946284971
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0009467067017130121
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found152 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07787456401781125
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found13 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.006549100369456887
#
#  I found36 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.019792719256640372
# Possible interactions
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0017666957036404226
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found149 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07869296450440051
#
#  I found13 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01118824128296202
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found23 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.012766440451814975
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found11 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.008052672228993168
# Possible interactions
#
#  I found340 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.16818765089691887
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012008589155807529
#
#  I found172 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07869296111686426
#
#  I found32 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01584648627873595
# Possible interactions
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.003332390797801966
#
#  I found20 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01432419676454744
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0009462730327986345
#
#  I found49 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02264233860170954
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found172 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07980952160538855
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found385 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.18533884430118627
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found24 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.017322316247275697
# Possible interactions
# Possible interactions
#
#  I found20 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009027211469744507
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found412 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.19635069882303346
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found87 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0013182995642461043
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00854625016938312
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found17 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.008061481152774004
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found71 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02957680597704844
#
#  I found9 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005147214324220935
# Possible interactions
#
#  I found79 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.030346284902936133
# Possible interactions
# Possible interactions
#
#  I found153 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07607080621024238
# Possible interactions
#
#  I found11 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.007085209923394749
# Possible interactions
# Possible interactions
#
#  I found33 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.019792719256640372
# Possible interactions
# Possible interactions
#
#  I found119 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.06696128246939478
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found143 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07701857725003218
#
#  I found67 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02788153071254348
#
#  I found17 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005625543003127284
# Possible interactions
#
#  I found149 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07747260621629039
#
#  I found61 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02788153071254348
#
#  I found160 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07790782521909194
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found160 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07831819660896086
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00025132215600828003
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found171 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07909234360127482
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found354 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.17618901563726228
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found128 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.06252034079005545
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found167 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07831819660896086
# Possible interactions
#
#  I found64 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.026953065946356863
# Possible interactions
#
#  I found58 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.026955614623279462
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found117 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.056910281596655767
# Possible interactions
# Possible interactions
#
#  I found50 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.027884030385099994
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found29 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.011184732149916218
# Possible interactions
# Possible interactions
#
#  I found140 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07977128641590721
# Possible interactions
# Possible interactions
#
#  I found147 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.08294767873489828
# Possible interactions
#
#  I found54 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.028756916957799507
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found165 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07959551867524668
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0018047469538795757
# Possible interactions
#
#  I found57 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.029576806918987397
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found66 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.03106793604209088
# Possible interactions
#
#  I found56 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0303462849789393
# Possible interactions
#
#  I found343 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.17618901563726228
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found165 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07869296450440051
# Possible interactions
#
#  I found165 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07924961979956172
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found62 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.03174430902738353
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01852327903878487
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found86 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.04056825768896564
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found33 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01732238657581637
# Possible interactions
# Possible interactions
#
#  I found169 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07973650936955085
# Possible interactions
#
#  I found48 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.027884030385099994
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found31 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.015846501759129057
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found98 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0013182995642461043
# Possible interactions
# Possible interactions
#
#  I found272 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.14446440971096713
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0009467067017130121
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012008589155807529
# Possible interactions
# Possible interactions
#
#  I found43 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.020106390906710226
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0004928513831348739
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found56 conflicts!
# This is out of 2000 trials, and the collision probability is 0.1515030815588435
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found345 conflicts!
# This is out of 2000 trials, and the collision probability is 0.2998503170076019
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found11 conflicts!
# This is out of 2000 trials, and the collision probability is 0.06123980083822598
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found23 conflicts!
# This is out of 2000 trials, and the collision probability is 0.09389064990717642
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found7 conflicts!
# This is out of 2000 trials, and the collision probability is 0.04802081949456108
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found311 conflicts!
# This is out of 2000 trials, and the collision probability is 0.29985031700760184
# Interaction at edge!
#
#  I found336 conflicts!
# This is out of 2000 trials, and the collision probability is 0.3002898584216464
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found322 conflicts!
# This is out of 2000 trials, and the collision probability is 0.3001928338567521
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found216 conflicts!
# This is out of 2000 trials, and the collision probability is 0.2878595233491397
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found4 conflicts!
# This is out of 2000 trials, and the collision probability is 0.034264199501967754
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found63 conflicts!
# This is out of 2000 trials, and the collision probability is 0.1550703640214984
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# ASTAR: 50
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 39 and 1 conflict at node 1035
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 39 and 1 conflict at node 994
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 9 and 42 conflict at node 1178
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 9 and 42 conflict at node 1178
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 28 and 20 conflict at node 546
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 28 and 20 conflict at node 546
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 36 and 8 conflict at node 255
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 28 and 20 conflict at node 587
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 34 and 5 conflict at node 877
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 36 and 8 conflict at node 255
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 9 and 42 conflict at node 1178
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 28 and 20 conflict at node 546
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 9 and 42 conflict at node 1095
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 15 and 1 conflict at node 870
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 28 and 20 conflict at node 546
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 23 and 1 conflict at node 954
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 36 and 8 conflict at node 255
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 9 and 42 conflict at node 1178
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 34 and 5 conflict at node 877
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 28 and 20 conflict at node 546
# ASTAR: 1
# ASTAR: 1
#
#
# Optimal Solution Found! Cost = 1423
# Time spent on probability count: 154.16806122199992
# Time spent on path finding: 6.172569572999996
# Time spent performing optimization: 179.638991335
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# ...
#
#  I found49 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02264233860170954
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found158 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07312377172093802
# Possible interactions
# Possible interactions
#
#  I found5 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0029170039146603397
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00654907689457985
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found50 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02140631744750304
# Possible interactions
#
#  I found53 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02492243973949827
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found10 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0033313872080946417
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found48 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.025969175066269622
# Possible interactions
#
#  I found51 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.026955614623279462
# Possible interactions
#
#  I found51 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.027884030385099994
# Possible interactions
#
#  I found70 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.028756916957799507
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found158 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0767305021582669
# Possible interactions
#
#  I found265 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.14944597390701717
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found5 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.003766757062690116
# Possible interactions
#
#  I found61 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.029576806918987397
# Possible interactions
# Possible interactions
#
#  I found21 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.015846501759129057
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004214795677472853
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found11 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004674335307684554
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found15 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005147214324220935
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found18 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005625543003127284
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found9 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0029342756601855218
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found74 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.03404324763820264
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found14 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.006109265811937821
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found179 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0878429439932821
# Possible interactions
#
#  I found165 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0867967439661643
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found74 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.035406163706038066
# Possible interactions
#
#  I found17 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.006596415586719759
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00119929813312247
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0005392574371317772
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found166 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.08566746794370365
# Possible interactions
# Possible interactions
#
#  I found75 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.035801794023261925
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found152 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07261197575605248
# Possible interactions
#
#  I found70 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0335261459570914
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found15 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.007085209062412554
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005132140343063994
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found139 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07924963706624046
# Possible interactions
#
#  I found170 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.08384468110233387
# Possible interactions
#
#  I found63 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.03617241072109248
# Possible interactions
#
#  I found67 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.036517032116888205
# Possible interactions
#
#  I found155 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07310566725705053
# Possible interactions
#
#  I found158 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07360155358708086
# Possible interactions
# Possible interactions
#
#  I found15 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009503575480484997
# Possible interactions
#
#  I found15 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009027299483226699
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found70 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.03683801747947618
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0019431474901014292
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0017787746667668536
# Possible interactions
#
#  I found22 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.010896109687107294
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0016197130735529728
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found248 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.13583304946284971
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found91 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0013182995642461043
# Possible interactions
#
#  I found54 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0011105413983559234
# Possible interactions
#
#  I found45 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012680421000170262
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found4 conflicts!
# This is out of 2000 trials, and the collision probability is 0.05520408278949295
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found17 conflicts!
# This is out of 2000 trials, and the collision probability is 0.10072652249104473
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found91 conflicts!
# This is out of 2000 trials, and the collision probability is 0.22878057224012677
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found2 conflicts!
# This is out of 2000 trials, and the collision probability is 0.06341463773887997
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found2 conflicts!
# This is out of 2000 trials, and the collision probability is 0.05520408278949299
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found31 conflicts!
# This is out of 2000 trials, and the collision probability is 0.09173828501397549
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found14 conflicts!
# This is out of 2000 trials, and the collision probability is 0.06747689666893804
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found81 conflicts!
# This is out of 2000 trials, and the collision probability is 0.22878057224012677
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found127 conflicts!
# This is out of 2000 trials, and the collision probability is 0.24966008502321377
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found198 conflicts!
# This is out of 2000 trials, and the collision probability is 0.28080643924137116
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Check3
# 5×21 DataFrames.DataFrame. Omitted printing of 15 columns
# │ Row │ name             │ Id    │ CBS   │ success │ lambda  │ epsilon │
# │     │ String           │ Int64 │ Bool  │ Bool    │ Float64 │ Float64 │
# ├─────┼──────────────────┼───────┼───────┼─────────┼─────────┼─────────┤
# │ 1   │ Timing_test_13_1 │ 1     │ false │ true    │ 0.2     │ 0.2     │
# │ 2   │ Timing_test_13_2 │ 2     │ false │ true    │ 0.2     │ 0.2     │
# │ 3   │ Timing_test_13_3 │ 3     │ false │ true    │ 0.2     │ 0.2     │
# │ 4   │ Timing_test_13_4 │ 4     │ false │ true    │ 0.2     │ 0.2     │
# │ 5   │ Timing_test_13_5 │ 5     │ false │ true    │ 0.2     │ 0.2     │

# %%
name = "Timing_test_13"
sub_name="Timing_test_13_1"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data5,num_trials=2000);
sub_name="Timing_test_13_2"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data6,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data5,num_trials=2000);
sub_name="Timing_test_13_3"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data6,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data5,num_trials=2000);
sub_name="Timing_test_13_4"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data6,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data5,num_trials=2000);
sub_name="Timing_test_13_5"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data6,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data5,num_trials=2000);
# Out:
# ASTAR: 50
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 12 and 46 conflict at node 741
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 3 and 8 conflict at node 786
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 3 and 8 conflict at node 827
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 17 and 1 conflict at node 344
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 20 and 32 conflict at node 304
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 350
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Optimal Solution Found! Cost = 1298
# Time spent on probability count: 554.8533675970002
# Time spent on path finding: 15.374277224999991
# Possible interactions
#
#  I found50 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.019792719256640372
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found21 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.00960549084184655
# Possible interactions
#
#  I found135 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07311839793039865
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0005392574371317772
# Possible interactions
#
#  I found8 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01852327903878487
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01852327903878487
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found47 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.02140631744750304
# Possible interactions
# Possible interactions
#
#  I found19 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.001681290111466449
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.002706071438775745
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0021505828495221803
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0025224636673007047
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found12 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.003766621182027203
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found15 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004211143359113715
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found13 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004674335307684554
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0017787746667668536
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found31 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.014324199782984215
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0007221709578985621
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0009462730327986345
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0009467067017130121
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012008589155807529
#
#  I found171 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07977128220254089
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0005392574371317772
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found36 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.015846501759129057
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found50 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0012680421000170262
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.004214795677472853
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found14 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005132146319483199
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found122 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.06252034079005545
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found140 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07311839793039865
# Possible interactions
#
#  I found127 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.06696128246939478
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found44 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.019792719256640372
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found17 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009608581077576495
# Possible interactions
# Possible interactions
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0038388377029472125
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found155 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0793263212388744
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found117 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.056910281596655767
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found173 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07618749053403714
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found169 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.079595519993677
# Possible interactions
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0018047469538795757
# Possible interactions
#
#  I found24 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.012766440451814975
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found19 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.009263718008829159
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found182 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0783085373339542
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found14 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005625543003127284
# Possible interactions
# Possible interactions
#
#  I found27 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01584648627873595
# Possible interactions
#
#  I found33 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01584648627873595
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found163 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07831819660896086
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found128 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0767305021582669
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0025169090956519225
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0021486892045596336
# Possible interactions
# Possible interactions
#
#  I found134 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07869296450440051
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found17 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.006549100369456887
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found93 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0025510910106438293
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found98 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.056910281596655767
# Possible interactions
# Possible interactions
#
#  I found9 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.005132146319483199
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found19 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.014324199782984215
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found30 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.01584648627873595
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found5 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0016506019613564751
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found9 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0029342756601855218
# Possible interactions
#
#  I found5 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0027857524735393807
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found12 conflicts!
# This is out of 2000 trials, and the collision probability is 0.07922876292652023
# Interaction at edge!
# Interaction at edge!
#
#  I found143 conflicts!
# This is out of 2000 trials, and the collision probability is 0.24966008502321377
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found2 conflicts!
# This is out of 2000 trials, and the collision probability is 0.07325425754406274
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found22 conflicts!
# This is out of 2000 trials, and the collision probability is 0.10722154277275608
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found5 conflicts!
# This is out of 2000 trials, and the collision probability is 0.0547380903243103
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found2 conflicts!
# This is out of 2000 trials, and the collision probability is 0.034264199501967754
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found169 conflicts!
# This is out of 2000 trials, and the collision probability is 0.2650195223738853
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found4 conflicts!
# This is out of 2000 trials, and the collision probability is 0.05520408278949295
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
#
#  I found12 conflicts!
# This is out of 2000 trials, and the collision probability is 0.10072652249104473
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# Interaction at edge!
# ASTAR: 50
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 3 and 8 conflict at node 827
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 4 and 34 conflict at node 683
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# Agents 12 and 46 conflict at node 741
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 215
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 217
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 216
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 33 conflict at node 256
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 4 and 34 conflict at node 683
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 37 and 33 conflict at node 588
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 24 and 33 conflict at node 384
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 4 and 34 conflict at node 683
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 47 and 34 conflict at node 727
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 35 conflict at node 434
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 48 and 49 conflict at node 800
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 24 and 43 conflict at node 424
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 43 and 10 conflict at node 550
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 19 and 24 conflict at node 791
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 14 and 10 conflict at node 590
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 9 and 44 conflict at node 1195
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 178
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 177
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 222
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 35 and 27 conflict at node 970
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 172
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 168
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 169
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 171
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 10 and 24 conflict at node 672
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 170
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 14 and 1 conflict at node 423
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 43 and 14 conflict at node 508
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 34 and 42 conflict at node 481
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 26 and 43 conflict at node 507
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 19 and 24 conflict at node 762
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 33 and 24 conflict at node 594
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 49 and 21 conflict at node 795
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 4 and 18 conflict at node 879
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 33 and 20 conflict at node 259
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 32 and 20 conflict at node 173
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 37 and 33 conflict at node 588
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 10 and 24 conflict at node 671
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 10 and 24 conflict at node 670
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 20 and 32 conflict at node 222
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 6 and 24 conflict at node 1044
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 49 and 24 conflict at node 800
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 34 and 42 conflict at node 481
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 42 and 24 conflict at node 515
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 43 and 14 conflict at node 546
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 19 and 24 conflict at node 842
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 20 and 32 conflict at node 222
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 37 and 33 conflict at node 588
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ...
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1

# %%
CSV.write("Timing_test_13.csv",data6)
