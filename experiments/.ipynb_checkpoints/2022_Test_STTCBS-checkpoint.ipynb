# %%
using CRCBS
# using LightGraphs, MetaGraphs
using Graphs
G = initialize_full_grid_graph_CT()
starts = [1,5,8,12]
goals = [4,1,2,25]
lambda = 0.5
epsilon = 0.1
t_delay = 0.5
mapf = MAPF(G,starts,goals,lambda,epsilon,t_delay)
# Out:
# ┌ Info: Precompiling CRCBS [edef75b8-3ac4-11e9-0392-bf149c536ee3]
# └ @ Base loading.jl:1273
# ERROR: LoadError: ArgumentError: Package Parameters does not have UnPack in its dependencies:
# - If you have Parameters checked out for development and have
#   added UnPack as a dependency but haven't updated your primary
#   environment's manifest file, try `Pkg.resolve()`.
# - Otherwise you may need to report an issue with Parameters
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:900
#  [2] include at ./boot.jl:328 [inlined]
#  [3] include_relative(::Module, ::String) at ./loading.jl:1105
#  [4] include(::Module, ::String) at ./Base.jl:31
#  [5] top-level scope at none:2
#  [6] eval at ./boot.jl:330 [inlined]
#  [7] eval(::Expr) at ./client.jl:425
#  [8] top-level scope at ./none:3
# in expression starting at /home/orianapeltzer/.julia/packages/Parameters/MK0O4/src/Parameters.jl:46
# ...

# %%
CTCBS(mapf)
# Out:
# ASTAR: 4
#
#
# Agents 2 and 1 conflict at node 3
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 2 and 3 conflict at node 2
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 4 and 2 conflict at node 14
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 3 and 1 conflict at node 4
# ASTAR: 1
#
#
# Agents 3 and 1 conflict at node 4
# ASTAR: 1
#
#
# Agents 3 and 1 conflict at node 4
# ASTAR: 1
#
#
# Optimal Solution Found! Cost = 19
# Time spent on probability count: 0.631541413
# Time spent on path finding: 0.4396895340000001
# (Array{LightGraphs.SimpleGraphs.SimpleEdge,1}[[Edge 1 => 2, Edge 2 => 3, Edge 3 => 4], [Edge 5 => 4, Edge 4 => 15, Edge 15 => 14, Edge 14 => 13, Edge 13 => 12, Edge 12 => 1], [Edge 8 => 7, Edge 7 => 6, Edge 6 => 5, Edge 5 => 5, Edge 5 => 4, Edge 4 => 3, Edge 3 => 2], [Edge 12 => 13, Edge 13 => 24, Edge 24 => 25]], 19, 0.631541413, 0.4396895340000001, [16, 1], 7)

# %%
using JLD
jldopen("../experiments/5test.jld","w") do file
    addrequire(file,CRCBS)
    write(file,"data",1)
end

# %%
using CRCBS
using Distributions
using HCubature
using CSV
using DataFrames

# %%
name = "Timing_test_5"
sub_name="Debugging_test_1_CBS"
st = run_cbs_particles(name; type="CBS", sub_name="", save_simulation=true)

# %%
name = "Redo_Timing_test_18"
num_agents = tuple(10)
grid_x = tuple(10)
grid_y = tuple(20)
filling_density = tuple(1.0)
lambda = 0.2
epsilon = 0.2
t_delay = 0.2
max_num_experiments = 5
num_trials = 2000

data = run_experiment_set_CRCBS(name,num_agents,grid_x,grid_y,filling_density,lambda,epsilon,t_delay,max_num_experiments,num_trials)
# Out:
# Started
# Check1
# Check2
# ASTAR: 10
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# ASTAR: 1
# ASTAR: 1
#
#
# Agents 7 and 4 conflict at node 94
# ASTAR: 1
# ...

# %%
data6[[1,9,11,12,13,14,15,16,17]]
# Out:
# 6×9 DataFrame. Omitted printing of 4 columns
# │ Row │ name            │ num_agents │ num_nodes │ num_edges │ solving_time │
# │     │ String          │ Int64      │ Int64     │ Int64     │ Float64      │
# ├─────┼─────────────────┼────────────┼───────────┼───────────┼──────────────┤
# │ 1   │ Timing_test_7_1 │ 6          │ 121       │ 280       │ 0.971295     │
# │ 2   │ Timing_test_7_1 │ 6          │ 121       │ 280       │ 1.45938      │
# │ 3   │ Timing_test_7_1 │ 6          │ 121       │ 280       │ 1.69348      │
# │ 4   │ Timing_test_7_1 │ 6          │ 121       │ 280       │ 1.69246      │
# │ 5   │ Timing_test_7_1 │ 6          │ 121       │ 280       │ 1.62477      │
# │ 6   │ Timing_test_7_1 │ 6          │ 121       │ 280       │ 1.64632      │

# %%
    data = DataFrame(name=String[],
    Id=Int64[],
    CBS=Bool[],
    success=Bool[],

    #MAPF contents
    lambda=Float64[],
    epsilon=Float64[],
    t_delay=Float64[],

    # Experiment properties
    num_trials=Int64[],
    num_agents=Int64[],
    cbs_time_steps=Int64[],
    num_nodes=Int64[],
    num_edges=Int64[],
    #mapf::MAPF

    # Result storage
    solving_time=Float64[], #Time it took to find a solution
    counting_time=Float64[],
    time_spent_on_astar=Float64[],
    num_interactions=Int64[],
    num_iterations = Int64[],

    solution_cost=Float64[], #Cost of computer solution in ideal case
    global_cp=Float64[],
    conflict_counts_locally=Vector{Float64}[],
    probability_error=Tuple{Float64,Float64}[]) #Mean, std
# Out:
# 0×21 DataFrame

# %%
name = "Timing_test_15"
sub_name="Timing_test_15_1"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.2,t_delay=1.0,dataframe=data,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data5,num_trials=2000);
data7 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data6,num_trials=2000);
sub_name="Timing_test_15_2"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.2,t_delay=1.0,dataframe=data7,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data5,num_trials=2000);
data7 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data6,num_trials=2000);
sub_name="Timing_test_15_3"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.2,t_delay=1.0,dataframe=data7,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data5,num_trials=2000);
data7 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data6,num_trials=2000);
sub_name="Timing_test_15_4"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.2,t_delay=1.0,dataframe=data7,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data5,num_trials=2000);
data7 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data6,num_trials=2000);
sub_name="Timing_test_15_5"
data2 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.2,t_delay=1.0,dataframe=data7,num_trials=2000);
data3 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.1,t_delay=1.0,dataframe=data2,num_trials=2000);
data4 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.05,t_delay=1.0,dataframe=data3,num_trials=2000);
data5 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.01,t_delay=1.0,dataframe=data4,num_trials=2000);
data6 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.001,t_delay=1.0,dataframe=data5,num_trials=2000);
data7 = run_problem(name; sub_name=sub_name, lambda=0.2,epsilon=0.0001,t_delay=1.0,dataframe=data6,num_trials=2000);
# Out:
# Optimal Solution Found! Cost = 90
# Time spent on probability count: 4.439019447000001
# Time spent on path finding: 0.526981527
# Possible interactions
#
#  I found39 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.021056059746911816
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found149 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.07043523057376266
# Possible interactions
# Possible interactions
#
#  I found13 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 1.7317788954528704e-28
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 3.580443647280725e-27
# Possible interactions
#
#  I found3 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 7.004170483698223e-26
# ...

# %%
CSV.write("Redo_Timing_test_15.csv",data7)
# Out:
# "Redo_Timing_test_15.csv"

# %% [markdown]
# #### CBS stats

# %%
name = "Timing_test_10_1"
sub_name="Timing_test_10_1"
stats = run_cbs_particles(name; type="CBS", sub_name=sub_name, save_simulation=true,get_stats=true)
stats[2]
# Out:
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.2193864377617696
# Possible interactions
#
#  I found2 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.11304372943869538
#
#  I found7 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.207411195413685
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.19620236862688153
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
# Possible interactions
#
#  I found6 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.22992465073204615
#
#  I found4 conflicts at a node!
# This is out of 2000 trials, and the collision probability is 0.0495925878144662
# Possible interactions
# Possible interactions
#
# ...

# %%
stats[2]
# Out:
# 0.018355886605754157

# %%
subname = "Debugging_test_1"
plot_optimal_nominal_paths(subname;type="CBS",graphfilename = "Debugging_test_1")

# %%
subname = "Debugging_test_1"
plot_optimal_nominal_paths(subname;type="CBS",graphfilename ="")

# %%
subname = "Debugging_test_1"
plot_simulations(subname;type="CBS",graphfilename = "Debugging_test_1",timehorizon=40,num_particles = 20)

# %%
using CRCBS
subname = "Debugging_test_1_optimal_2"
savedir= "Dbg1/CRCBS_optimal_2/"
run_problem("Debugging_test_1";optimal=true, sub_name=subname, save_simulation=true,lambda=1.0,epsilon=0.001,t_delay=1.0)
plot_optimal_nominal_paths(subname;type="CRCBS",graphfilename = "Debugging_test_1",savedir=savedir)
plot_simulations(subname;type="CRCBS",graphfilename = "Debugging_test_1",timehorizon=40,num_particles = 20,savedir=savedir)

# %%
using CRCBS
subname = "Debugging_test_1_sim1"
graphfilename = "Debugging_test_1"
plot_simulations(subname;type="CRCBS",graphfilename=graphfilename,timehorizon=30,num_particles = 20)

# %%
using CRCBS
using Distributions
using HCubature

name = "Convergence_test"
num_agents = (3,8,10)
grid_x = tuple(10)
grid_y = tuple(10)
filling_density = tuple(0.8)
lambda = 0.2
epsilon = 0.9
t_delay = 0.5
max_num_experiments = 3
num_trials = 1000

data2 = run_convergence_tests_CRCBS(name,num_agents,grid_x,grid_y,filling_density,lambda,epsilon,t_delay,max_num_experiments,num_trials)

# %%
exp_set.data[2].solving_time

# %%
save_experiment_set(exp_set)

# %%
n1 = 17.0
t1 = 17.0
n2 = 17.0
t2 = 17.0
nn = 1.0
lambda = 0.2
y = 0.0
t = 400.0

# %%
get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)

# %%
(1-cdf(Gamma(nn,lambda),abs(t2-t1+y)))

# %%
pdf(Gamma(n1,lambda), t+y)

# %%
using HCubature
function get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)

    function f(x)
        y = x[1]
        t = x[2]
        density = (1-cdf(Gamma(nn,lambda),abs(t2-t1+y))) * pdf(Gamma(n1,lambda), t) * pdf(Gamma(n2,lambda),t-y)
        return density
    end

    function g(x)
        y = x[1]
        t = x[2]
        density = (1-cdf(Gamma(nn,lambda),abs(t2-t1+y))) * pdf(Gamma(n1,lambda), t+y) * pdf(Gamma(n2,lambda),t)
        return density
    end
    
    function h(x)
        y = x[1]
        t = x[2]
        density = (1-cdf(Gamma(nn,lambda),abs(t2-t1-y))) * pdf(Gamma(n1,lambda), t) * pdf(Gamma(n2,lambda),t-y)
        return density
    end

    a = [-100.0;0.0]
    b = [0.0,100.0]
    m = [0.0;0.0]
    n = [100.0,100.0]
    
    bound = max(t1+n1,t2+n2)*lambda + 30.0
    #bound = 20.0 
    
    o = bound.*[-1.0,-1.0]
    p = bound.*[1.0,1.0]
    # C1,err1 = hcubature(f,a,b,maxevals=10^7)
    # C2,err2 = hcubature(g,m,n,maxevals=10^7)
    # C = C1 + C2
    # err = err1 + err2
    C, err = hcubature(h,o,p,maxevals=10^8)
    #C, err = hcubature(h,o,p,rtol = 10^(-3))

    return C, err
end

# %%
using Distributions
function count_conflicts(n1,t1,n2,t2,nn,lambda,num_particles)
    EA1 = rand(Gamma(n1,lambda),num_particles)
    EA2 = rand(Gamma(n2,lambda),num_particles)
    ed1 = rand(Gamma(nn,lambda),num_particles)
    ed2 = rand(Gamma(nn,lambda),num_particles)
    
    r1_arrivals = t1 .+ EA1
    r1_departures = r1_arrivals + ed1
    r2_arrivals = t2 .+ EA2
    r2_departures = r2_arrivals + ed2
    
    num_conflicts =length(findall(((r2_departures-r1_arrivals).>0) .& ((r1_departures-r2_arrivals).>0)   ))
    
    return num_conflicts/num_particles
end

# %%
n1 = rand(1:50)
t1 = rand()*50
n2 = rand(1:50)
t2 = rand()*50
nn = rand(1:5)
lambda = rand()
print("n1: ", n1, " t1: ", t1, " n2: ", n2, " t2: ", t2, " nn: ", nn, " lambda: ", lambda)
sleep(1)
theoretical_cp = get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)
count_conflicts(n1,t1,n2,t2,nn,lambda,10000)

# %%
theoretical_cp

# %%
get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)

# %%
get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)

# %%
n1= 55
t1= 6.7
n2= 13 
t2= 13.23
nn= 46
lambda= 0.08
theoretical_cp = get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)
experimental_cp = count_conflicts(n1,t1,n2,t2,nn,lambda,2000000)

# %%
using DataFrames
using Statistics
using Plots
df = DataFrame(num_particles=Int64[],cp=Float64[],experimental_cp=Float64[],etas=Float64[])
x_list = [1,2,5,10,20,50,100,200,500,1000,2000,5000,10000,20000,50000,100000]
max_attempts = 10000
# Defining global variables
n1 = 0
n2 = 0
t1 = 0
t2 = 0
nn = 0
lambda = 0
for k in 1:200
    #println("Next k")
    theoretical_cp = 0.0
    attempts = 0
    while theoretical_cp < 0.01 && attempts < max_attempts
        n1 = rand(1:20)
        t1 = rand()*20
        n2 = rand(1:20)
        t2 = rand()*20
        nn = rand(1:5)
        lambda = rand()
        theoretical_cp = get_collision_probability_node2(n1,t1,n2,t2,nn,lambda)[1]
        attempts += 1
    end
    for x in x_list
        experimental_cp = count_conflicts(n1,t1,n2,t2,nn,lambda,x)
        ecart_relatif = abs(experimental_cp-theoretical_cp)/theoretical_cp
        if abs(ecart_relatif) > 0.5 && x > 2000
            println("Exception case occured! Returned something really wrong.")
            println("n1: ", n1, " t1: ", t1, " n2: ", n2, " t2: ", t2, " nn: ", nn, " lambda: ", lambda)
        end
        push!(df,[x,theoretical_cp,experimental_cp,ecart_relatif])
    end
end

ys = []
stds = []
for x in x_list
    indexes = findall((df[1].==x) .& (df[2] .> 0.01) .& (df[2] .< 1.0) .& (df[3] .> 0.01))
    values = df[4][indexes]
    y = mean(values)
    stdv = std(values)
    append!(ys,y)
    append!(stds,stdv)
end

plot(x_list,ys,yerror=stds,xscale = :log10)

# %%
plot(x_list,ys,yerror=stds,xscale = :log10,xlabel="Number of particles per simulation", ylabel="Relative error")

# %%
indexes = findall(df[1].==1)
df[1][indexes]

# %%
using JLD
save_experiment_set(exp_set)

# %%
plot_SVtime_vs_nrobots(["results/003Experiment_Set_001.jld"])

# %%
using JLD
exp_s = load("results/001Experiment_Set_001.jld")

# %%
using CSV
using DataFrames

# %%
CSV.write("Timing_test_9.csv",data6)
# Out:
# "Timing_test_9.csv"

# %%
retrieved_data = DataFrame(CSV.File("Timing_test_10.csv"))
# Out:
# 30×21 DataFrame. Omitted printing of 15 columns
# │ Row │ name             │ Id     │ CBS   │ success │ lambda   │ epsilon  │
# │     │ String⍰          │ Int64⍰ │ Bool⍰ │ Bool⍰   │ Float64⍰ │ Float64⍰ │
# ├─────┼──────────────────┼────────┼───────┼─────────┼──────────┼──────────┤
# │ 1   │ Timing_test_10_1 │ 1      │ false │ true    │ 0.2      │ 0.2      │
# │ 2   │ Timing_test_10_2 │ 2      │ false │ true    │ 0.2      │ 0.2      │
# │ 3   │ Timing_test_10_3 │ 3      │ false │ true    │ 0.2      │ 0.2      │
# │ 4   │ Timing_test_10_4 │ 4      │ false │ true    │ 0.2      │ 0.2      │
# │ 5   │ Timing_test_10_5 │ 5      │ false │ true    │ 0.2      │ 0.2      │
# │ 6   │ Timing_test_10_1 │ 0      │ false │ true    │ 0.2      │ 0.1      │
# │ 7   │ Timing_test_10_1 │ 0      │ false │ true    │ 0.2      │ 0.05     │
# │ 8   │ Timing_test_10_1 │ 0      │ false │ true    │ 0.2      │ 0.01     │
# │ 9   │ Timing_test_10_1 │ 0      │ false │ false   │ 0.2      │ 0.001    │
# ...

# %%
data10.global_cp[5]
# Out:
# 0.38591038199141403

# %%
for k in 1:5
    idxs = findall(retrieved_data[1].==string("Timing_test_11_",k))
    seg = [data11.global_cp[idx] for idx in idxs]
    plot!(epsilons,seg)
end

# %%
using Plots
using DataFrames

epsilons = [0.2 0.1 0.05 0.01 0.001 0.0001]'
data10 = DataFrame(CSV.File("Timing_test_10.csv"));
#cbs10 = [, 0.018355886605754157 ]
data11 = DataFrame(CSV.File("Timing_test_11.csv"));
data12 = DataFrame(CSV.File("Timing_test_12.csv"));
data9 = DataFrame(CSV.File("Timing_test_9.csv"));
data15 = DataFrame(CSV.File("Timing_test_15.csv"));
data17 = DataFrame(CSV.File("Timing_test_17.csv"));
b = plot()
# 8 agents
for k in 1:5
    idxs = findall(data12[1].==string("Timing_test_12_",k))
    seg3 = [data12.global_cp[idx] for idx in idxs]
    if k==1
        plot!(b, epsilons,seg3,color=1,label="8 agents",leg=:topleft,title="Conflict Probability",xlabel="\\epsilon",ylabel="Global conflict probability",linewidth=1.5)
    else
        plot!(b, epsilons,seg3,color=1,label="",linewidth=1.5)
    end
end
for k in 1:5
    idxs = findall(data9[1].==string("Timing_test_9_",k))
    seg9 = [data9.global_cp[idx] for idx in idxs]
    plot!(b, epsilons,seg9,color=1,label="",linewidth=1.5)
end

#10 agents
for k in 1:5
    idxs = findall(data10[1].==string("Timing_test_10_",k))
    seg = [data10.global_cp[idx] for idx in idxs]
    println(seg)
    if k==1
        plot!(b, epsilons,seg,color=2,label="10 agents",linewidth=1.5)
    else
        plot!(b, epsilons,seg,color=2,label="",linewidth=1.5)
    end
end
for k in 1:5
    idxs2 = findall(data11[1].==string("Timing_test_11_",k))
    seg2 = [data11.global_cp[idx] for idx in idxs2]
    println(seg2)
    plot!(b, epsilons,seg2,color=2,label="",linewidth=1.5)
end

# 12 agents
for k in [1,3]
    idxs = findall(data15[1].==string("Timing_test_15_",k))
    seg15 = [data15.global_cp[idx] for idx in idxs[1:end-1]]
    if k==1
        plot!(b, epsilons[1:end-1],seg15,color=3,label="12 agents",linewidth=1.5)
    else
        plot!(b, epsilons[1:end-1],seg15,color=3,label="",linewidth=1.5)
    end
end
for k in [4,5]
    idxs = findall(data17[1].==string("Timing_test_17_",k))
    seg17 = [data17.global_cp[idx] for idx in idxs]
    plot!(b, epsilons,seg17,color=3,label="",linewidth=1.5)
end
for k in [3]
    idxs = findall(data17[1].==string("Timing_test_17_",k))
    seg17 = [data17.global_cp[idx] for idx in idxs[1:end-1]]
    plot!(b, epsilons[1:end-1],seg17,color=3,label="",linewidth=1.5)
end

b

savefig("Conflict_Probability.pdf")
# Out:
# [0.237581, 0.0603829, 0.0834463, 0.0109494, 0.0, 0.0]
# [0.426134, 0.287271, 0.126433, 0.0, 0.0, 0.0]
# [0.191418, 0.0750114, 0.0660419, 0.0, 0.0149527, 0.0]
# [0.211577, 0.0510299, 0.0642047, 0.0095, 0.0, 0.0]
# [0.38591, 0.310785, 0.122678, 0.00499475, 0.0, 0.0]
# [0.0542305, 0.0788798, 0.050902, 0.0, 0.0, 0.0]
# [0.0556926, 0.0728561, 0.0668407, 0.013477, 0.0, 0.001]
# [0.446329, 0.274935, 0.0134483, 0.0208759, 0.0, 0.001]
# [0.168927, 0.169923, 0.0981696, 0.001, 0.0, 0.0]
# [0.268273, 0.080015, 0.0, 0.0193681, 0.001, 0.0]

# %%
idxs
# Out:
# 6-element Array{Int64,1}:
#   5
#  26
#  27
#  28
#  29
#  30

# %%
[parse(Float64, ss[1:end-1]) for ss in split(mylist[2:end])]

# %%
idxs = findall(data2[2].==0.0)

# %%
using Plots

# %%
#10x10
s103 = [0.838268164,
6.046413626,
6.027422407,
7.395781768,
26.407926724,
31.336873806,
41.524267629];
s105=[0.893268709,
4.795210845,
19.110496669,
22.543244984,
36.582929956,
4986.554715911,
4768.027270284];

#20x20
s111 = [0.064633767
0.274766333
0.260972871
1.545473181
2.507382777
2.629956959
2.895344171
];
s113 = [0.061916355
0.653404443
2.845976515
7.396081836
8.54012509
7.431730897
9.182312699
];
s114 = [0.129586989
1.171401308
0.387884926
0.759089416
5.419553174
4.928526927
7.232669675
];
s115 = [0.069100104
0.331322326
3.303154952
12.394167096
23.277246283
13.451959194
18.012314043
];

#10x20
s182 = [0.023246729
1.321609182
5.698565537
4.992412894
5.345482836
8.56747408
31.550292027
];

s183 = [0.035169102
0.222554014
0.2580369
0.255792038
0.654430586
0.861935238
3.784606099
];

# %%
plot([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s103[2:end]),color=1,linewidth=1.5,xlabel="\\epsilon",ylabel="Computation time (s)",leg=:topright,label="10 x 10 grid")
scatter!([0.22],[s103[1]],color=1,markersize=3,label="")
plot!([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s182[2:end]),color=2,linewidth=1.5,label="10 x 20 grid")
scatter!([0.22],[s182[1]],color=2,markersize=3,label="")
plot!([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s183[2:end]),color=2,linewidth=1.5,label="")
scatter!([0.22],[s183[1]],color=2,markersize=3,label="")
plot!([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s111[2:end]),color=3,linewidth=1.5,label="20 x 20 grid")
scatter!([0.22],[s111[1]],color=3,markersize=3,label="")
plot!([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s113[2:end]),color=3,linewidth=1.5,label="")
scatter!([0.22],[s113[1]],color=3,markersize=3,label="")
plot!([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s114[2:end]),color=3,linewidth=1.5,label="")
scatter!([0.22],[s114[1]],color=3,markersize=3,label="")
plot!([0.0001,0.001,0.01,0.05,0.1,0.2],reverse(s115[2:end]),color=3,linewidth=1.5,label="")
scatter!([0.22],[s115[1]],color=3,markersize=3,label="")

#savefig("ComputationTimeNR.pdf")
